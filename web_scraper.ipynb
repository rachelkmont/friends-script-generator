# %% [markdown]
# # Web Scraper for Friends Scripts

# %% [markdown]
# Episodes are found on Crazy For Friends, a Friends fansite.
#
# [Crazy For Friends](https://www.livesinabox.com/friends/scripts.shtml)

# %% [markdown]
# *Disclaimer for scripts: This project is in no way associated with Friends, Warner Bros, NBC or Bright/Kauffman/Crane Productions. This project is for educational purposes only*

# %% [markdown]
# ### Install Dependencies

# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %% [markdown]
# ### Import Libraries

# %%
import requests
import os
from bs4 import BeautifulSoup

# %% [markdown]
# ### Fetch the Webpage

# %%
# Base URL of the website
base_url = "https://www.livesinabox.com/friends/"
# URL of the page containing the script links
scripts_page_url = "https://www.livesinabox.com/friends/scripts.shtml"

# Send a request to the website
response = requests.get(scripts_page_url)
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ### Folder to save script files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Colab/friends"
# Out:
# data  friends_script_generation.ipynb  web_scraper.ipynb

# %%
# Directory to save script files
scripts_dir = "/content/drive/My Drive/Colab/friends/scripts_data"
os.makedirs(scripts_dir, exist_ok=True)  # This will create the directory if it doesn't exist

# %% [markdown]
# ### Locate the Links to Scripts

# %% [markdown]
# The scripts on the webpage are likely linked through anchor tags (<a>). You'll need to identify how these links are structured in the HTML and write code to extract them. For example:

# %%
# Find all the <a> tags that contain the links to the scripts
script_links = soup.find_all('a', href=True)

# %% [markdown]
# ### Extract and Visit Each Script Link

# %% [markdown]
# You will iterate over the extracted links, visit each page, and scrape the script text. This can be complex, as you'll need to identify the HTML structure of each script page.

# %%
## og one
# Loop through all the found <a> tags to extract and save the scripts
for link in script_links:
    href = link.get('href')
    if href and 'season' in href:
        # Construct the full URL for the script page
        script_url = base_url + href
        # Fetch the script page
        script_response = requests.get(script_url)
        script_soup = BeautifulSoup(script_response.content, 'html.parser')

        # The script title is in the <h1> tag
        title_tag = script_soup.find('h1')
        title_text = title_tag.get_text(strip=True) if title_tag else 'Untitled'
        filename = f"{title_text}.txt".replace('/', ' ').replace(' ', '_')
        filepath = os.path.join(scripts_dir, filename)

        # Find all paragraph tags and concatenate their text
        paragraphs = script_soup.find_all('p')
        script_text = '\n'.join(paragraph.get_text(strip=True) for paragraph in paragraphs)

        # Write the script text to a file
        with open(filepath, 'w', encoding='utf-8') as file:
            file.write(script_text)
        print(f"Saved script: {filename}")

# %%
# Loop through all the found <a> tags to extract and save the scripts
for link in script_links:
    href = link.get('href')
    if href and 'season' in href:
        script_url = base_url + href
        script_response = requests.get(script_url)
        script_soup = BeautifulSoup(script_response.content, 'html.parser')

        title_tag = script_soup.find('h1')
        if title_tag:
            title_text = title_tag.get_text(strip=True)
            if title_text.startswith("The One"):
                filename = f"{title_text}.txt".replace('/', ' ').replace(' ', '_')
                filepath = os.path.join(scripts_dir, filename)

                paragraphs = script_soup.find_all('p')
                script_text = '\n'.join(paragraph.get_text(strip=True) for paragraph in paragraphs)

                with open(filepath, 'w', encoding='utf-8') as file:
                    file.write(script_text)
                print(f"Saved script: {filename}")
# Out:
# Saved script: The_One_With_Joey's_Big_Break.txt
# Saved script: The_One_In_Vegas.txt
# Saved script: The_One_After_Vegas.txt
# Saved script: The_One_Where_Ross_Hugs_Rachel.txt
# Saved script: The_One_With_Ross’s_Denial.txt
# Saved script: The_One_Where_Joey_Loses_His_Insurance.txt
# Saved script: The_One_With_Joey’s_Porsche.txt
# Saved script: The_One_The_Last_Night.txt
# Saved script: The_One_Where_Phoebe_Runs.txt
# Saved script: The_One_With_Ross’s_Teeth.txt
# Saved script: The_One_Where_Ross_Got_High.txt
# Saved script: The_One_With_The_Routinue.txt
# Saved script: The_One_With_The_Apothecary_Table.txt
# Saved script: The_One_With_The_Joke.txt
# Saved script: The_One_With_Rachel’s_Sister.txt
# Saved script: The_One_Where_Chandler_Can’t_Cry.txt
# Saved script: The_One_That_Could_Have_Been.txt
# Saved script: The_One_With_The_Unagi.txt
# Saved script: The_One_Where_Ross_Dates_A_Student.txt
# Saved script: The_One_With_Joey’s_Fridge.txt
# Saved script: The_One_With_Mac_and_C.H.E.E.S.E..txt
# Saved script: The_One_Where_Ross_Meets_Elizabeth’s_Dad.txt
# Saved script: The_One_Where_Paul’s_The_Man.txt
# Saved script: The_One_With_The_Ring.txt
# Saved script: The_One_With_The_Proposal.txt
# Saved script: The_One_With_Monica’s_Thunder.txt
# Saved script: The_One_With_Rachel’s_Book.txt
# Saved script: The_One_With_Phoebe’s_Cookies.txt
# Saved script: The_One_With_Rachel’s_Assistant.txt
# Saved script: The_One_With_The_Engagement_Picture.txt
# Saved script: The_One_With_The_Nap_Partners.txt
# Saved script: The_One_With_Ross’s_Book.txt
# Saved script: The_One_Where_Chandler_Doesn’t_Like_Dogs.txt
# Saved script: The_One_With_All_The_Candy.txt
# Saved script: The_One_With_the_Holiday_Armadillo.txt
# Saved script: The_One_With_All_The_Cheesecakes.txt
# Saved script: The_One_Where_They’re_Up_All_Night.txt
# Saved script: The_One_Where_Rosita_Dies.txt
# Saved script: The_One_Where_They_All_Turn_Thirty.txt
# Saved script: The_One_With_Joey’s_New_Brain.txt
# Saved script: The_One_With_The_Truth_About_London.txt
# Saved script: The_One_With_The_Cheap_Wedding_Dress.txt
# Saved script: The_One_With_Joey’s_Award.txt
# Saved script: The_One_With_Ross_and_Monica’s_Cousin.txt
# Saved script: The_One_With_Rachel’s_Big_Kiss.txt
# Saved script: The_One_With_The_Vows.txt
# Saved script: The_One_With_Chandler’s_Dad.txt
# Saved script: The_One_With_Chandler_and_Monica’s_Wedding.txt
# Saved script: The_One_After_"I_Do".txt
# Saved script: The_One_With_The_Red_Sweater.txt
# Saved script: The_One_Where_Rachel_Tells….txt
# Saved script: The_One_With_The_Videotape.txt
# Saved script: The_One_With_Rachel’s_Date.txt
# Saved script: The_One_With_The_Halloween_Party.txt
# Saved script: The_One_With_The_Stain.txt
# Saved script: The_One_With_The_Stripper.txt
# Saved script: The_One_With_The_Rumor.txt
# Saved script: The_One_With_Monica’s_Boots.txt
# Saved script: The_One_With_Ross’_Big_Step_Forward.txt
# Saved script: The_One_Where_Joey_Dates_Rachel.txt
# Saved script: The_One_Where_Chandler_Takes_a_Bath.txt
# Saved script: The_One_With_The_Secret_Closet.txt
# Saved script: The_One_Where_Joey_Tells_Rachel.txt
# Saved script: The_One_With_The_Tea_Leaves.txt
# Saved script: The_One_In_Massapequa.txt
# Saved script: The_One_With_Joey’s_Interview.txt
# Saved script: The_One_With_The_Baby_Shower.txt
# Saved script: The_One_With_The_Cooking_Class.txt
# Saved script: The_One_Where_Rachel_Is_Late.txt
# Saved script: The_One_Where_Rachel_Has_A_Baby.txt
# Saved script: The_One_Where_No_One_Proposes.txt
# Saved script: The_One_Where_Emma_Cries.txt

# %% [markdown]
# And now we should have all of our scripts!

# %%
# Checking our data folder
# !ls "/content/drive/My Drive/Colab/friends/scripts_data"
# Out:
# 'The_One_After_"I_Do".txt'
#  The_One_After_Ross_Says_Rachel.txt
#  The_One_After_the_Superbowl.txt
#  The_One_After_Vegas.txt
#  The_One_At_The_Beach.txt
#  The_One_Hundredth.txt
#  The_One_In_Massapequa.txt
#  The_One_In_Vegas.txt
#  The_One_That_Could_Have_Been.txt
#  The_One_The_Last_Night.txt
#  The_One_The_Morning_After.txt
#  The_One_Where_Chandler_Can’t_Cry.txt
#  The_One_Where_Chandler_Can’t_Remember_Which_Sister.txt
#  The_One_Where_Chandler_Crosses_a_Line.txt
#  The_One_Where_Chandler_Doesn’t_Like_Dogs.txt
#  The_One_Where_Chandler_Takes_a_Bath.txt
#  The_One_Where_Dr._Remoray_Dies.txt
#  The_One_Where_Eddie_Moves_In.txt
# "The_One_Where_Eddie_Won't_Go.txt"
#  The_One_Where_Emma_Cries.txt
#  The_One_Where_Everyone_Finds_Out.txt
#  The_One_Where_Joey_Dates_Rachel.txt
#  The_One_Where_Joey_Loses_His_Insurance.txt
#  The_One_Where_Joey_Moves_Out.txt
#  The_One_Where_Joey_Tells_Rachel.txt
#  The_One_Where_Monica_and_Richard_Are_Friends.txt
# 'The_One_Where_Monica_Gets_a_New_Roommate_(The_Pilot-The_Uncut_Version).txt'
#  The_One_Where_Mr._Heckles_Dies.txt
#  The_One_Where_Nana_Dies_Twice.txt
#  The_One_Where_No_One_Proposes.txt
# "The_One_Where_No-one's_Ready.txt"
#  The_One_Where_Old_Yeller_Dies.txt
#  The_One_Where_Paul’s_The_Man.txt
#  The_One_Where_Phoebe_Hates_PBS.txt
#  The_One_Where_Phoebe_Runs.txt
#  The_One_Where_Rachel_and_Ross..._You_Know.txt
#  The_One_Where_Rachel_Finds_Out.txt
#  The_One_Where_Rachel_Has_A_Baby.txt
#  The_One_Where_Rachel_Is_Late.txt
#  The_One_Where_Rachel_Quits.txt
#  The_One_Where_Rachel_Smokes.txt
#  The_One_Where_Rachel_Tells….txt
#  The_One_Where_Rosita_Dies.txt
#  The_One_Where_Ross_and_Rachel_Take_A_Break.txt
# "The_One_Where_Ross_Can't_Flirt.txt"
#  The_One_Where_Ross_Dates_A_Student.txt
#  The_One_Where_Ross_Finds_Out.txt
#  The_One_Where_Ross_Got_High.txt
#  The_One_Where_Ross_Hugs_Rachel.txt
