# %% [markdown]
# ## EDA & Preprocessing

# %% [markdown]
# In this notebook we will do some data exploration, and ensure that the scripts are small enough to be processed for machine learning!

# %% [markdown]
# *Disclaimer for scripts: This project is in no way associated with Friends, Warner Bros, NBC or Bright/Kauffman/Crane Productions. This project is for educational purposes only.*

# %% [markdown]
# ## Environment Set-Up

# %%
import os
import glob
import re
import tensorflow as tf
import numpy as np
from collections import Counter
import torch
import pickle
from transformers import pipeline, AdamW, GPT2Tokenizer, GPT2LMHeadModel
from tqdm.auto import tqdm
import torch.nn as nn  # For neural network modules
import torch.optim as optim  # For optimizers like SGD, Adam, etc.
import torch.nn.functional as F  # For functions like activations
from torch.utils.data import DataLoader, Dataset  # For creating data loaders and custom datasets
from torch.nn.utils.rnn import pad_sequence
from torch.optim import AdamW
from shutil import copyfile

# %% [markdown]
# ## Get the Data
# The data is scripts from all 10 seaons, retrieved via web scraping.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
directory_path = '/content/drive/My Drive'
directory_files = os.listdir(directory_path)

# %%
directory_files
# Out:
# ['Honors Biology Spring Final Exam Study Guide 2013.docx',
#  'Hr. World Lit. - Annotated Resources.docx.gdoc',
#  'Annotated Bibliographies.doc.gdoc',
#  "Annotations - Dante's Inferno.docx.gdoc",
#  'photo 2.JPG',
#  'Vive le Taureau Chapter 4.docx',
#  'Vive le Taureau Chapter 4 (1).gdoc',
#  'Vive le Taureau Chapter 4.gdoc',
#  'Revenge Play and Amleth.docx',
#  'Revenge Play and Amleth.gdoc',
#  'Changes in Russia 1750-1914.pages.zip',
#  'Saint John Vianney.gdoc',
#  'Letters Against and For Constitution.docx',
#  'Letters Against and For Constitution.docx.gdoc',
#  'Sophia Tannir',
#  'Reflexives, problematic voyage, EU, Inspector Maigret-2.docx.gdoc',
#  'Untitled document (2).gdoc',
#  'heyy.gdoc',
#  'Church, yo..gslides',
#  "Strohmann and Bridget's Wedding.gdoc",
#  'She Could Be a Farmer in those Clothes!!! (Part Deux).gslides',
#  'Chem Handout-Big Idea 1.gdoc',
#  'Big Idea 1.gslides',
#  'AP Gov Study Guide.gdoc',
#  'Island Project.gslides',
#  'John 5:1-47.gslides',
#  'SophiaGene Chart1.docx',
#  'SophiaGene Chart1.docx.gdoc',
#  'Alltech-Sophia Tannir 44x36.gslides',
#  'Eleda Lyrics..gdoc',
#  'Top 25.gdoc',
#  'Bahamas.gslides',
#  'Sophia Tannir-Common App.gdoc',
#  'Apartments!.gsheet',
#  'Soph and Jayce Scream :).gsheet',
#  'Apartments.gsheet',
#  'Alltech Mentorship Poster-Sophia Tannir.gslides',
#  'Statement of Purpose.gdoc',
#  'New SoP.gdoc',
#  'SoP jc and meié.gdoc',
#  'SOP AGAIN xoxo.gdoc',
#  'Untitled document (1).gdoc',
#  'Extenuating Circumstances Document.gdoc',
#  'Current SoP - for Jeff.gdoc',
#  'kate bishop.gdoc',
#  'Iowa SoP.gdoc',
#  'Columbia SoP.gdoc',
#  'Indiana University Personal Statement.gdoc',
#  'NYU Statement of Purpose.gdoc',
#  'NYU Personal History Statement.gdoc',
#  'help xx.gdoc',
#  'Brown University Personal Statement.gdoc',
#  'Michigan Personal Statement.gdoc',
#  'Michigan SoP.gdoc',
#  'Colab Notebooks',
#  'Vanderbilt SoP.gdoc',
#  'Washington University SoP.gdoc',
#  'Minnesota Diversity Statement.gdoc',
#  'Minnesota Personal Statement.gdoc',
#  'Nashville Apartments xx.gsheet',
#  'wandavision wan wandavision.gdoc',
#  'Untitled document.gdoc',
#  'Moving Companies.gsheet',
#  'Graduate School.gsheet',
#  'Johns Hopkins SoP.gdoc',
#  'EDA Review.gdoc',
#  'json_test.json',
#  'arabian_nights.json',
#  'Narrative_Arc',
#  'Group Firm Research Project.docx',
#  'Cycling in London.gdoc',
#  'Health Sciences Consent.docx',
#  'Copy of Health Sciences Consent.docx',
#  'id_dgxkey.pub',
#  'app for ethics.gdoc',
#  'PROTEST-ER.gslides',
#  'Protest Model Proposed Pipeline.gslides',
#  'IP Law.gdoc',
#  'AI Policies in Canada.gdoc',
#  'Vanderbilt University_PPT_Template_2022.potx',
#  'Untitled presentation.gslides',
#  'Vanderbilt University_PPT_Template_2022.gslides',
#  'C4 for June 7.gdoc',
#  'LegiScan.gslides',
#  'Copy of A List of Questions (Asked and Unasked), Curated Created by Emma Becker.gdoc',
#  'Media Framing in Protest Research.gslides',
#  'Jennifer (1).zip',
#  'Jennifer.zip',
#  'tannir-assignment5.ipynb',
#  'Interactive NFL Statistics Dashboard with MongoDB.gdoc',
#  'Copy of spotify_millsongdata.csv',
#  'Copy of prepare_lyrics.py',
#  'QB Prospect Analysis Using Neural Networks and LLMs.gslides',
#  'things i want :D.gdoc',
#  'Job Search',
#  'Day 26 Group 1.gdoc',
#  'Updated_NFL_Statistics_Presentation.pptx',
#  'NFL Statistics with MongoDB (1).gslides',
#  'Copy of American Football Annual Championship MK Campaign by Slidesgo.gslides',
#  'NFL Statistics with MongoDB.gslides',
#  'Copy of Transformers Syllabus 2023 Spring.gdoc',
#  'Homework 0.gsheet',
#  'linkedin post.gdoc',
#  'VUMC Cover Letter.gdoc',
#  'Gradient Cover Letter.gdoc',
#  'Jobs.gsheet',
#  'LLM Review.gsheet',
#  'Big Data Scaling Milestone 0.docx',
#  'Milestone 1.gdoc',
#  'UK Bioinformatics.gdoc',
#  'final_df (1) (1).csv',
#  'final_df (1).csv',
#  'paradigm_results.csv',
#  'sentiment_results.csv',
#  'Friends Script Generator.gslides',
#  'friends']

# %%
# Define the path to the directory
directory = "/content/drive/My Drive/friends/cleaned_scripts"

# %% [markdown]
# ## Explore the Data

# %%
# Initialize counters
dialogues_per_main_character = Counter({'Rachel': 0, 'Ross': 0, 'Monica': 0, 'Chandler': 0, 'Joey': 0, 'Phoebe': 0})
total_word_count = 0
total_scenes = 0
total_lines = 0
script_count = 0

# Process each file
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        script_count += 1
        filepath = os.path.join(directory, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            script_content = file.read()

        # Count dialogues for main characters
        for line in script_content.split('\n'):
            if ':' in line:
                character, dialogue = line.split(':', 1)
                character = character.strip()
                if character in dialogues_per_main_character:
                    dialogues_per_main_character[character] += 1
                    word_count = len(dialogue.split())
                    total_word_count += word_count
                    total_lines += 1

# Calculate averages
average_word_count_per_script = total_word_count / script_count if script_count else 0
average_scenes_per_script = total_scenes / script_count if script_count else 0
average_words_per_line = total_word_count / total_lines if total_lines else 0

# Display results
print("Number of Dialogues per Main Character:")
for character, count in dialogues_per_main_character.items():
    print(f"{character}: {count}")

print(f"\nAverage Word Count per Script: {average_word_count_per_script}")
print(f"Average Number of Scenes per Script: {average_scenes_per_script}")
print(f"Average Number of Words per Line: {average_words_per_line}")
# Out:
# Number of Dialogues per Main Character:
# Rachel: 7090
# Ross: 6718
# Monica: 6206
# Chandler: 6255
# Joey: 6114
# Phoebe: 5502
#
# Average Word Count per Script: 1541.3829787234042
# Average Number of Scenes per Script: 0.0
# Average Number of Words per Line: 7.648937574237825

# %%
# Define the locations to count
locations = ['Central Perk', "Joey and Rachel's", "Monica's", "Monica and Rachel's", "Chandler and Joey's", "Ross's", "Phoebe's", "Moondance Diner"]
locations_counter = Counter({location: 0 for location in locations})

# Process each file
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        filepath = os.path.join(directory, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            script_content = file.read()

        # Count occurrences of specified locations
        for line in script_content.split('\n'):
            if line.startswith('[') and line.endswith(']'):
                scene_description = line.strip('[]').split(',')[0]
                for location in locations:
                    if location in scene_description:
                        locations_counter[location] += 1

# Display results
print("Scene Count for Specific Locations:")
for location, count in locations_counter.items():
    print(f"{location}: {count}")
# Out:
# Scene Count for Specific Locations:
# Central Perk: 278
# Joey and Rachel's: 37
# Monica's: 35
# Monica and Rachel's: 191
# Chandler and Joey's: 58
# Ross's: 26
# Phoebe's: 13
# Moondance Diner: 6

# %% [markdown]
#  ## Break scripts up into scenes

# %% [markdown]
# To tokenize the data, the max lenth is 1,024. To ensure that the scripts stay understandable, we will break scripts up into their respective scenes to help this (and also hopefully help the model be able to write a short scene.)

# %%
def split_script_into_scenes(script_filepath, output_directory):
    with open(script_filepath, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    scene_lines = []
    scene_count = 1
    base_filename = os.path.splitext(os.path.basename(script_filepath))[0]

    for line in lines:
        if line.strip().startswith('[Scene:') and scene_lines:
            # Save current scene to file
            scene_filename = f"{base_filename}_{scene_count}.txt"
            with open(os.path.join(output_directory, scene_filename), 'w', encoding='utf-8') as scene_file:
                scene_file.write(''.join(scene_lines))

            # Reset for next scene
            scene_lines = []
            scene_count += 1

        scene_lines.append(line)

    # Save the last scene
    if scene_lines:
        scene_filename = f"{base_filename}_{scene_count}.txt"
        with open(os.path.join(output_directory, scene_filename), 'w', encoding='utf-8') as scene_file:
            scene_file.write(''.join(scene_lines))

def split_all_scripts(input_directory, output_directory):
    for filename in os.listdir(input_directory):
        if filename.endswith('.txt'):
            split_script_into_scenes(os.path.join(input_directory, filename), output_directory)
            print(f"Processed {filename}")

# %%
input_directory = '/content/drive/My Drive/friends/cleaned_scripts'
output_directory = '/content/drive/My Drive/friends/split_scripts'

# Creates the folder if it does not exist
os.makedirs(output_directory, exist_ok=True)

# %%
split_all_scripts(input_directory, output_directory)
# Out:
# Processed The_One_Where_Monica_Gets_a_New_Roommate_(The_Pilot-The_Uncut_Version).txt
# Processed The_One_With_the_Sonogram_at_the_End.txt
# Processed The_One_With_the_Thumb.txt
# Processed The_One_With_George_Stephanopoulos.txt
# Processed The_One_With_the_East_German_Laundry_Detergent.txt
# Processed The_One_With_the_Butt.txt
# Processed The_One_With_the_Blackout.txt
# Processed The_One_Where_Nana_Dies_Twice.txt
# Processed The_One_Where_Underdog_Gets_Away.txt
# Processed The_One_With_the_Monkey.txt
# Processed The_One_With_Mrs._Bing.txt
# Processed The_One_With_the_Dozen_Lasagnas.txt
# Processed The_One_With_the_Boobies.txt
# Processed The_One_With_the_Candy_Hearts.txt
# Processed The_One_With_the_Stoned_Guy.txt
# Processed The_One_With_Two_Parts,_part_1.txt
# Processed The_One_With_Two_Parts,_Part_2.txt
# Processed The_One_With_All_The_Poker.txt
# Processed The_One_Where_the_Monkey_Gets_Away.txt
# Processed The_One_With_the_Evil_Orthodontist.txt
# Processed The_One_With_The_Fake_Monica.txt
# Processed The_One_With_the_Ick_Factor.txt
# Processed The_One_With_the_Birth.txt
# Processed The_One_Where_Rachel_Finds_Out.txt
# Processed The_One_With_Ross'_New_Girlfriend.txt
# Processed The_One_With_the_Breast_Milk.txt
# Processed The_One_Where_Mr._Heckles_Dies.txt
# Processed The_One_With_Phoebe's_Husband.txt
# Processed The_One_With_Five_Steaks_and_an_Eggplant.txt
# Processed The_One_With_the_Baby_on_the_Bus.txt
# Processed The_One_Where_Ross_Finds_Out.txt
# Processed The_One_With_the_List.txt
# Processed The_One_With_Phoebe's_Dad.txt
# Processed The_One_With_Russ.txt
# Processed The_One_With_the_Lesbian_Wedding.txt
# Processed The_One_After_the_Superbowl.txt
# Processed The_One_With_the_Prom_Video.txt
# Processed The_One_Where_Rachel_and_Ross..._You_Know.txt
# Processed The_One_Where_Joey_Moves_Out.txt
# Processed The_One_Where_Eddie_Moves_In.txt
# Processed The_One_Where_Dr._Remoray_Dies.txt
# Processed The_One_Where_Eddie_Won't_Go.txt
# Processed The_One_Where_Old_Yeller_Dies.txt
# Processed The_One_With_the_Two_Bullies.txt
# Processed The_One_With_the_Two_Parties.txt
# Processed The_One_With_the_Chicken_Pox.txt
# Processed The_One_With_Barry_and_Mindy's_Wedding.txt
# Processed The_One_With_the_Princess_Leia_Fantasy.txt
# Processed The_One_Where_No-one's_Ready.txt
# Processed The_One_With_the_Jam.txt
# Processed The_One_With_The_Metaphorical_Tunnel.txt
# Processed The_One_With_Frank_Jr..txt
# Processed The_One_With_The_Flashback.txt
# Processed The_One_With_the_Race_Car_Bed.txt
# Processed The_One_With_The_Giant_Poking_Device.txt
# Processed The_One_With_The_Football.txt
# Processed The_One_Where_Rachel_Quits.txt
# Processed The_One_Where_Chandler_Can’t_Remember_Which_Sister.txt
# Processed The_One_With_All_The_Jealousy.txt
# Processed The_One_Where_Monica_and_Richard_Are_Friends.txt
# Processed The_One_With_Phoebe’s_Ex-Partner.txt
# Processed The_One_Where_Ross_and_Rachel_Take_A_Break.txt
# Processed The_One_The_Morning_After.txt
# Processed The_One_Without_The_Ski_Trip.txt
# Processed The_One_With_The_Hypnosis_Tape.txt
# Processed The_One_With_The_Tiny_T-shirt.txt
# Processed The_One_With_The_Dollhouse.txt
# Processed The_One_With_A_Chick._And_A_Duck.txt
# Processed The_One_With_The_Screamer.txt
# Processed The_One_With_Ross's_Thing.txt
# Processed The_One_With_The_Ultimate_Fighting_Champion.txt
# Processed The_One_At_The_Beach.txt
# Processed The_One_With_The_Jellyfish.txt
# Processed The_One_With_The_Cat.txt
# Processed The_One_With_The_‘Cuffs.txt
# Processed The_One_With_The_Ballroom_Dancing.txt
# Processed The_One_With_Joey's_New_Girlfriend.txt
# Processed The_One_With_The_Dirty_Girl.txt
# Processed The_One_Where_Chandler_Crosses_a_Line.txt
# Processed The_One_With_Chandler_in_a_Box.txt
# Processed The_One_Where_They’re_Gonna_PARTY!.txt
# Processed The_One_With_The_Girl_From_Poughkeepsie.txt
# Processed The_One_With_Phoebe’s_Uterus.txt
# Processed The_One_With_The_Embryos.txt
# Processed The_One_With_Rachel’s_Crush.txt
# Processed The_One_With_Joey’s_Dirty_Day.txt
# Processed The_One_With_All_The_Rugby.txt
# Processed The_One_With_The_Fake_Party.txt
# Processed The_One_With_The_Free_Porn.txt
# Processed The_One_With_Rachel’s_New_Dress.txt
# Processed The_One_With_All_The_Haste.txt
# Processed The_One_With_All_the_Wedding_Dresses.txt
# Processed The_One_With_The_Invitation.txt
# Processed The_One_With_The_Worst_Best_Man_Ever.txt
# Processed The_One_With_Ross’s_Wedding_Parts_I_and_II.txt
# Processed The_One_After_Ross_Says_Rachel.txt
# Processed The_One_With_All_The_Kissing.txt
# Processed The_One_Hundredth.txt
# Processed The_One_Where_Phoebe_Hates_PBS.txt
# Processed The_One_With_All_the_Kips.txt
# Processed The_One_With_The_Yeti.txt
# Processed The_One_Where_Ross_Moves_In.txt
# Processed The_One_With_The_Thanksgiving_Flashbacks.txt
# Processed The_One_With_Ross's_Sandwich.txt
# Processed The_One_With_The_Inappropriate_Sister.txt
# Processed The_One_With_All_The_Resolutions.txt
# Processed The_One_With_Chandler's_Work_Laugh.txt
# Processed The_One_With_Joey's_Bag.txt
# Processed The_One_Where_Everyone_Finds_Out.txt
# Processed The_One_With_The_Girl_Who_Hits_Joey.txt
# Processed The_One_With_A_Cop.txt
# Processed The_One_With_Rachel's_Inadvertant_Kiss.txt
# Processed The_One_Where_Rachel_Smokes.txt
# Processed The_One_Where_Ross_Can't_Flirt.txt
# Processed The_One_With_The_Ride_Along.txt
# Processed The_One_With_The_Ball.txt
# Processed The_One_With_Joey's_Big_Break.txt
# Processed The_One_In_Vegas.txt
# Processed The_One_After_Vegas.txt
# Processed The_One_Where_Ross_Hugs_Rachel.txt
# Processed The_One_With_Ross’s_Denial.txt
# Processed The_One_Where_Joey_Loses_His_Insurance.txt
# Processed The_One_With_Joey’s_Porsche.txt
# Processed The_One_The_Last_Night.txt
# Processed The_One_Where_Phoebe_Runs.txt
# Processed The_One_With_Ross’s_Teeth.txt
# Processed The_One_Where_Ross_Got_High.txt
# Processed The_One_With_The_Routinue.txt
# Processed The_One_With_The_Apothecary_Table.txt
# Processed The_One_With_The_Joke.txt
# Processed The_One_With_Rachel’s_Sister.txt
# Processed The_One_Where_Chandler_Can’t_Cry.txt
# Processed The_One_That_Could_Have_Been.txt
# Processed The_One_With_The_Unagi.txt
# Processed The_One_Where_Ross_Dates_A_Student.txt
# Processed The_One_With_Joey’s_Fridge.txt
# Processed The_One_With_Mac_and_C.H.E.E.S.E..txt
# Processed The_One_Where_Ross_Meets_Elizabeth’s_Dad.txt
# Processed The_One_Where_Paul’s_The_Man.txt
# Processed The_One_With_The_Ring.txt
# Processed The_One_With_The_Proposal.txt
# Processed The_One_With_Monica’s_Thunder.txt
# Processed The_One_With_Rachel’s_Book.txt
# Processed The_One_With_Phoebe’s_Cookies.txt
# Processed The_One_With_Rachel’s_Assistant.txt
# Processed The_One_With_The_Engagement_Picture.txt
# Processed The_One_With_The_Nap_Partners.txt
# Processed The_One_With_Ross’s_Book.txt
# Processed The_One_Where_Chandler_Doesn’t_Like_Dogs.txt
# Processed The_One_With_All_The_Candy.txt
# Processed The_One_With_the_Holiday_Armadillo.txt
# Processed The_One_With_All_The_Cheesecakes.txt
# Processed The_One_Where_They’re_Up_All_Night.txt
# Processed The_One_Where_Rosita_Dies.txt
# Processed The_One_Where_They_All_Turn_Thirty.txt
# Processed The_One_With_Joey’s_New_Brain.txt
# Processed The_One_With_The_Truth_About_London.txt
# Processed The_One_With_The_Cheap_Wedding_Dress.txt
# Processed The_One_With_Joey’s_Award.txt
# Processed The_One_With_Ross_and_Monica’s_Cousin.txt
# Processed The_One_With_Rachel’s_Big_Kiss.txt
# Processed The_One_With_The_Vows.txt
# Processed The_One_With_Chandler’s_Dad.txt
# Processed The_One_With_Chandler_and_Monica’s_Wedding.txt
# Processed The_One_After_"I_Do".txt
# Processed The_One_With_The_Red_Sweater.txt
# Processed The_One_Where_Rachel_Tells….txt
# Processed The_One_With_The_Videotape.txt
# Processed The_One_With_Rachel’s_Date.txt
# Processed The_One_With_The_Halloween_Party.txt
# Processed The_One_With_The_Stain.txt
# Processed The_One_With_The_Stripper.txt
# Processed The_One_With_The_Rumor.txt
# Processed The_One_With_Monica’s_Boots.txt
# Processed The_One_With_Ross’_Big_Step_Forward.txt
# Processed The_One_Where_Joey_Dates_Rachel.txt
# Processed The_One_Where_Chandler_Takes_a_Bath.txt
# Processed The_One_With_The_Secret_Closet.txt
# Processed The_One_Where_Joey_Tells_Rachel.txt
# Processed The_One_With_The_Tea_Leaves.txt
# Processed The_One_In_Massapequa.txt
# Processed The_One_With_Joey’s_Interview.txt
# Processed The_One_With_The_Baby_Shower.txt
# Processed The_One_With_The_Cooking_Class.txt
# Processed The_One_Where_Rachel_Is_Late.txt
# Processed The_One_Where_Rachel_Has_A_Baby.txt
# Processed The_One_Where_No_One_Proposes.txt
# Processed The_One_Where_Emma_Cries.txt

# %% [markdown]
# ## Tokenize Data

# %% [markdown]
# Now, we will tokenize the data, and ensure that each script is under the token limit of 1,024.

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')
# Out:
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
tokenized_scripts = []

for filename in os.listdir(output_directory):
    if filename.endswith('.txt'):
        filepath = os.path.join(output_directory, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            script = file.read()
            # Tokenize the script and add special tokens
            tokenized_script = tokenizer.encode(script, add_special_tokens=True)
            tokenized_scripts.append(tokenized_script)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2755 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# ## Removing texts that are over token limit

# %% [markdown]
# Now, we will remove the texts that are over the token limit.

# %%
### Counting number of text files

# Initialize a counter
total_scripts = 0

# Iterate over the files in the directory
for filename in os.listdir(output_directory):
    if filename.endswith('.txt'):
        total_scripts += 1

# Print the total number of script files
print(f"Total number of scripts: {total_scripts}")
# Out:
# Total number of scripts: 2509

# %%
# Initialize a counter
scripts_exceeding_limit = 0

# Iterate over the scripts
for filename in os.listdir(output_directory):
    if filename.endswith('.txt'):
        filepath = os.path.join(output_directory, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            script_content = file.read()

        # Tokenize the script
        tokens = tokenizer.encode(script_content)

        # Check if token count exceeds 1024
        if len(tokens) > 1024:
            scripts_exceeding_limit += 1
            print(f"Script '{filename}' exceeds 1024 tokens.")

# Print the total number of scripts exceeding the limit
print(f"Total scripts exceeding 1024 tokens: {scripts_exceeding_limit}")
# Out:
# Script 'The_One_Where_Monica_Gets_a_New_Roommate_(The_Pilot-The_Uncut_Version)_1.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Sonogram_at_the_End_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Thumb_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_George_Stephanopoulos_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_East_German_Laundry_Detergent_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Butt_4.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Nana_Dies_Twice_11.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Underdog_Gets_Away_13.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Monkey_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Monkey_8.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Stoned_Guy_9.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Stoned_Guy_12.txt' exceeds 1024 tokens.
# Script 'The_One_With_Two_Parts,_Part_2_7.txt' exceeds 1024 tokens.
# Script 'The_One_With_All_The_Poker_8.txt' exceeds 1024 tokens.
# Script 'The_One_Where_the_Monkey_Gets_Away_6.txt' exceeds 1024 tokens.
# Script 'The_One_Where_the_Monkey_Gets_Away_7.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Rachel_Finds_Out_3.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Mr._Heckles_Dies_5.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Mr._Heckles_Dies_9.txt' exceeds 1024 tokens.
# Script 'The_One_With_Five_Steaks_and_an_Eggplant_6.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_List_9.txt' exceeds 1024 tokens.
# Script 'The_One_With_Phoebe's_Dad_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_Phoebe's_Dad_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_Russ_5.txt' exceeds 1024 tokens.
# Script 'The_One_With_Russ_9.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Lesbian_Wedding_1.txt' exceeds 1024 tokens.
# Script 'The_One_After_the_Superbowl_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Prom_Video_1.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Rachel_and_Ross..._You_Know_2.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Joey_Moves_Out_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_Barry_and_Mindy's_Wedding_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_Barry_and_Mindy's_Wedding_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Metaphorical_Tunnel_4.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Football_4.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Football_5.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Rachel_Quits_8.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Chandler_Can’t_Remember_Which_Sister_6.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Chandler_Can’t_Remember_Which_Sister_13.txt' exceeds 1024 tokens.
# Script 'The_One_The_Morning_After_14.txt' exceeds 1024 tokens.
# Script 'The_One_Without_The_Ski_Trip_11.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Screamer_4.txt' exceeds 1024 tokens.
# Script 'The_One_At_The_Beach_6.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Chandler_Crosses_a_Line_4.txt' exceeds 1024 tokens.
# Script 'The_One_With_Chandler_in_a_Box_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_Chandler_in_a_Box_8.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Embryos_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Embryos_8.txt' exceeds 1024 tokens.
# Script 'The_One_With_Joey’s_Dirty_Day_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Fake_Party_5.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Fake_Party_6.txt' exceeds 1024 tokens.
# Script 'The_One_With_All_The_Haste_5.txt' exceeds 1024 tokens.
# Script 'The_One_With_All_The_Haste_7.txt' exceeds 1024 tokens.
# Script 'The_One_After_Ross_Says_Rachel_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_All_The_Kissing_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_All_The_Kissing_8.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Phoebe_Hates_PBS_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Yeti_12.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Thanksgiving_Flashbacks_9.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Thanksgiving_Flashbacks_11.txt' exceeds 1024 tokens.
# Script 'The_One_With_All_The_Resolutions_11.txt' exceeds 1024 tokens.
# Script 'The_One_With_Joey's_Bag_12.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Everyone_Finds_Out_11.txt' exceeds 1024 tokens.
# Script 'The_One_With_A_Cop_8.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Ross_Can't_Flirt_2.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Ross_Can't_Flirt_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Ride_Along_11.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Ball_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_Joey's_Big_Break_6.txt' exceeds 1024 tokens.
# Script 'The_One_In_Vegas_3.txt' exceeds 1024 tokens.
# Script 'The_One_After_Vegas_3.txt' exceeds 1024 tokens.
# Script 'The_One_The_Last_Night_2.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Phoebe_Runs_2.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Phoebe_Runs_3.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Ross_Got_High_3.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Ross_Got_High_7.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Routinue_2.txt' exceeds 1024 tokens.
# Script 'The_One_With_Rachel’s_Sister_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_Rachel’s_Sister_4.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Chandler_Can’t_Cry_7.txt' exceeds 1024 tokens.
# Script 'The_One_That_Could_Have_Been_2.txt' exceeds 1024 tokens.
# Script 'The_One_That_Could_Have_Been_4.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Unagi_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_Joey’s_Fridge_12.txt' exceeds 1024 tokens.
# Script 'The_One_With_Mac_and_C.H.E.E.S.E._9.txt' exceeds 1024 tokens.
# Script 'The_One_With_Mac_and_C.H.E.E.S.E._10.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Ross_Meets_Elizabeth’s_Dad_5.txt' exceeds 1024 tokens.
# Script 'The_One_With_Monica’s_Thunder_9.txt' exceeds 1024 tokens.
# Script 'The_One_With_Monica’s_Thunder_11.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Chandler_Doesn’t_Like_Dogs_4.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Chandler_Doesn’t_Like_Dogs_7.txt' exceeds 1024 tokens.
# Script 'The_One_With_the_Holiday_Armadillo_11.txt' exceeds 1024 tokens.
# Script 'The_One_Where_They_All_Turn_Thirty_5.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Truth_About_London_9.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Vows_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Vows_4.txt' exceeds 1024 tokens.
# Script 'The_One_With_Chandler_and_Monica’s_Wedding_6.txt' exceeds 1024 tokens.
# Script 'The_One_With_Chandler_and_Monica’s_Wedding_27.txt' exceeds 1024 tokens.
# Script 'The_One_After_"I_Do"_3.txt' exceeds 1024 tokens.
# Script 'The_One_After_"I_Do"_4.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Red_Sweater_4.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Red_Sweater_12.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Rachel_Tells…_11.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Halloween_Party_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Halloween_Party_5.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Rumor_3.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Rumor_4.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Joey_Tells_Rachel_10.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Tea_Leaves_4.txt' exceeds 1024 tokens.
# Script 'The_One_In_Massapequa_4.txt' exceeds 1024 tokens.
# Script 'The_One_In_Massapequa_5.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Baby_Shower_5.txt' exceeds 1024 tokens.
# Script 'The_One_With_The_Baby_Shower_9.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Rachel_Is_Late_4.txt' exceeds 1024 tokens.
# Script 'The_One_Where_Rachel_Has_A_Baby_26.txt' exceeds 1024 tokens.
# Script 'The_One_Where_No_One_Proposes_10.txt' exceeds 1024 tokens.
# Total scripts exceeding 1024 tokens: 115

# %% [markdown]
# 115 scripts have a token indices sequence length longer than the specified maximum sequence length for this model, which will result in indexing errors. Because this is a small amount (~5 %)  we will remove them.

# %%
# Paths
original_directory = "/content/drive/My Drive/Colab/friends/split_scripts"
new_directory = "/content/drive/My Drive/Colab/friends/processed_scripts"

# Create new directory if it doesn't exist
if not os.path.exists(new_directory):
    os.makedirs(new_directory)

# %%
# Initialize tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Process files
for filename in os.listdir(original_directory):
    if filename.endswith('.txt'):
        filepath = os.path.join(original_directory, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            script_content = file.read()

        # Tokenize and check length
        tokens = tokenizer.encode(script_content)
        if len(tokens) <= 1024:  # GPT-2 token limit
            # Copy file to new directory
            new_filepath = os.path.join(new_directory, filename)
            copyfile(filepath, new_filepath)

print("Finished processing scripts.")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2755 > 1024). Running this sequence through the model will result in indexing errors
# Finished processing scripts.
